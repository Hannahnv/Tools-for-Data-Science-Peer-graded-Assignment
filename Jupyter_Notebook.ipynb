# %% [markdown]
# <center>
#     <img src="https://s3-api.us-geo.objectstorage.softlayer.net/cf-courses-data/CognitiveClass/Logos/organization_logo/organization_logo.png" width="300" alt="cognitiveclass.ai logo"  />
# </center>

# %% [markdown]
# # My Jupyter Notebook on IBM Watson Studio

# %% [markdown]
# ### Hang Nguyen
# #### Student

# %% [markdown]
# ### I am interested in data science because I want to help people better understand their diseases and health conditions through data in the field of Healthcare.

# %% [markdown]
# ### The following code will show subtraction between two numbers

# %%
a = 10
b = 8
c = a - b
print(c)
# Out:
# 2

# %% [markdown]
# ##### ● Taylor Swift
# ##### ● Adele
# ##### ● The Weekend
# ##### ● Ed Sheeran
# ##### ● Bruno Mars
